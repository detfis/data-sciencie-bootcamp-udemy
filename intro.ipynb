# %% [markdown]
# <a href="https://colab.research.google.com/github/detfis/data-sciencie-bootcamp-udemy/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello colab")
# Out:
# Hello colab
